# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# 2023-05-26 12:30:38.074074: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 13480051416023217712
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 22708420608
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 2222961238769076974
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:2d:00.0, compute capability: 8.9"
# xla_global_id: 416903419
# ]
# 2023-05-26 12:30:39.733855: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-26 12:30:39.738633: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-26 12:30:39.738831: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-26 12:30:40.250468: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-26 12:30:40.250654: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-26 12:30:40.250785: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-26 12:30:40.250891: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /device:GPU:0 with 21656 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:2d:00.0, compute capability: 8.9

# %%
import os
import numpy as np
from numba import cuda
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import ray
import tensorflow as tf
from wordcloud import WordCloud
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc, precision_recall_curve
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import SGD, RMSprop, Adam
from sklearn.model_selection import GridSearchCV
from tune_sklearn import TuneSearchCV
import gc
from tensorflow.keras import backend as K
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier

ray.init(num_cpus=32, num_gpus=1)
os.environ["CUDA_VISIBLE_DEVICES"]="0"
os.environ["TF_GPU_ALLOCATOR"] = 'cuda_malloc_async'
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  # Restrict TensorFlow to only allocate a specific fraction of memory on the first GPU
  try:
    tf.config.experimental.set_virtual_device_configuration(
        gpus[0],
        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=(21658*0.8))])
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Virtual devices must be set before GPUs have been initialized
    print(e)


from tensorflow.compat.v1 import ConfigProto
config = ConfigProto()
config.gpu_options.allow_growth = True
config.gpu_options.per_process_gpu_memory_fraction=0.8

# Load the data
df_train = pd.read_csv('email_data_slim.csv')
df_val = pd.read_csv('processed_validation_data.csv')

# Ensure that there are no NA values in the 'subject' and 'body' columns
df_train = df_train.dropna(subset=['body'])
df_val = df_val.dropna(subset=['body'])

stemmer = PorterStemmer()

def stem_words(text):
    text = str(text)  # Ensure the text is a string
    word_tokens = word_tokenize(text)
    stems = [stemmer.stem(word) for word in word_tokens]
    return ' '.join(stems)

# nltk.download('punkt')
# df_train['body'] = df_train['body'].apply(stem_words)
# df_val['body'] = df_val['body'].apply(stem_words)

# Tokenization
tokenizer = Tokenizer()
tokenizer.fit_on_texts(df_train['body'])
sequences_train = tokenizer.texts_to_sequences(df_train['body'])
sequences_val = tokenizer.texts_to_sequences(df_val['body'])
word_index = tokenizer.word_index

max_length = max(max(len(s) for s in sequences_train), max(len(s) for s in sequences_val)) 

# Padding
data_train = pad_sequences(sequences_train, maxlen=max_length)
data_val = pad_sequences(sequences_val, maxlen=max_length)

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(data_train, df_train['label'], test_size=0.2, random_state=42)

# Define a callback to clear training outputs at the end of every training step
class ClearTrainingOutput(tf.keras.callbacks.Callback):
    def on_train_end(*args, **kwargs):
        IPython.display.clear_output(wait = True)

class CleanGpuUsage(tf.keras.callbacks.Callback):
    def on_trial_result(self, iteration, trials, trial, result, **info):
        print(f"Got result: {result['metric']}")
        device = cuda.get_current_device()
        device.reset()

# Define a callback to save the model at the best epoch and the last epoch
class SaveModelCallback(tf.keras.callbacks.Callback):
    def __init__(self, models_directory):
        super(SaveModelCallback, self).__init__()
        self.models_directory = models_directory
        self.trial_directory = None
        self.best_epoch = -1

    def on_train_begin(self, logs=None):
        # Create a sub-directory for the current trial
        self.trial_directory = os.path.join(self.models_directory, f'trial_{self.model.trial_id}')
        os.makedirs(self.trial_directory, exist_ok=True)

#     def on_epoch_end(self, epoch, logs=None):
#         model_name = f'model_{epoch}.h5'
#         model_path = os.path.join(self.trial_directory, model_name)
#         self.model.save(model_path)
#         # Save the model at the best epoch
#         if logs is not None and 'val_loss' in logs:
#             current_val_loss = logs['val_loss']
#             if self.best_epoch == -1 or current_val_loss < self.best_val_loss:
#                 self.best_epoch = epoch
#                 self.best_val_loss = current_val_loss
#                 best_model_name = f'best_model.h5'
#                 best_model_path = os.path.join(self.trial_directory, best_model_name)
#                 self.model.save(best_model_path)

    def on_train_end(self, logs=None):
            last_model_name = f'last_model.h5'
            last_model_path = os.path.join(self.trial_directory, last_model_name)
            self.model.save(last_model_path)

# Directory to save the models
models_directory = 'ray_results'

# Specify callbacks
save_model_callback = SaveModelCallback(models_directory)
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001)
callbacks = [ClearTrainingOutput(), early_stopping, save_model_callback]
# Out:
# 2023-05-26 12:30:43,400	INFO worker.py:1625 -- Started a local Ray instance.
# 1 Physical GPUs, 1 Logical GPUs
# 2023-05-26 12:30:44.213249: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-26 12:30:44.213512: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-26 12:30:44.213664: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-26 12:30:44.214307: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-26 12:30:44.214475: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-26 12:30:44.214614: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-26 12:30:44.214793: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-26 12:30:44.214933: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-26 12:30:44.215026: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21656 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:2d:00.0, compute capability: 8.9

# %%
# Define a custom Keras model with a trial_id attribute
class CustomKerasModel(Sequential):
    def __init__(self, trial_id, **kwargs):
        super().__init__(**kwargs)
        self.trial_id = trial_id


# Wrap build_model function in a KerasClassifier with the custom model to support saving model on each trial
def build_model(trial_id=None, num_lstm_layers=1, num_dense_layers=1, lstm_units=64, dense_units=64, dropout_rate=0.0, optimizer='adam'):
    model = CustomKerasModel(trial_id=trial_id)
    model.add(Embedding(input_dim=len(word_index)+1, output_dim=128, input_length=max_length))
    for i in range(num_lstm_layers):
        if i == num_lstm_layers - 1:
            model.add(LSTM(lstm_units, return_sequences=False))
        else:
            model.add(LSTM(lstm_units, return_sequences=True))
    for _ in range(num_dense_layers):
        model.add(Dense(dense_units, activation='relu'))
        model.add(Dropout(dropout_rate))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model

# %%
# Wrap your build_model function in a KerasClassifier
model = KerasClassifier(build_fn=build_model, verbose=1)

# Define the hyperparameters as a dictionary
param_grid = {
    'optimizer': ['Adam', 'RMSprop', 'SGD'],
    'num_lstm_layers': [1, 2, 3],
    'lstm_units': [32, 64],
    'num_dense_layers': [1, 2, 3],
    'dense_units': [32, 64],
    'dropout_rate': [0.2],
    'batch_size': [128],
    'epochs': [50]
}

# TuneSearchCV instead of GridSearchCV
tune_search = TuneSearchCV(
    model,
    param_grid,
    early_stopping=False,  # Enables early stopping
    max_iters=1,  # Maximum iterations in the Ray Tune library
    use_gpu=True,  # Allows Ray Tune to use GPU scheduling
    search_optimization="bayesian",  # Type of optimization algorithm
    n_jobs=-1,  # Number of jobs to run concurrently
    cv=3,  # Cross-validation splitting strategy
    verbose=1
)

# Fit the model
# tune_search.fit(X_train, y_train)
tune_search.fit(X_train, y_train, validation_data=(X_test, y_test), callbacks=[early_stopping, CleanGpuUsage(), save_model_callback], verbose=2)

# Get the best parameters and score
print("Best parameter combination: ", tune_search.best_params_)
print("Best score: ", tune_search.best_score_)
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2023-05-26 15:04:08</td></tr>
# <tr><td>Running for: </td><td>02:33:20.93        </td></tr>
# <tr><td>Memory:      </td><td>26.5/125.7 GiB     </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 0/32 CPUs, 0/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name         </th><th>status    </th><th>loc              </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  dense_units</th><th style="text-align: right;">  dropout_rate</th><th style="text-align: right;">  epochs</th><th style="text-align: right;">  lstm_units</th><th style="text-align: right;">  num_dense_layers</th><th style="text-align: right;">  num_lstm_layers</th><th>optimizer  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  split0_test_score</th><th style="text-align: right;">  split1_test_score</th><th style="text-align: right;">  split2_test_score</th></tr>
# </thead>
# <tbody>
# <tr><td>_Trainable_29df148b</td><td>TERMINATED</td><td>172.17.0.2:658018</td><td style="text-align: right;">         128</td><td style="text-align: right;">           36</td><td style="text-align: right;">           0.2</td><td style="text-align: right;">      50</td><td style="text-align: right;">          52</td><td style="text-align: right;">                 3</td><td style="text-align: right;">                2</td><td>SGD        </td><td style="text-align: right;">     1</td><td style="text-align: right;">        1579.56 </td><td style="text-align: right;">           0.774138</td><td style="text-align: right;">           0.787202</td><td style="text-align: right;">           0.766396</td></tr>
# <tr><td>_Trainable_5ac53558</td><td>TERMINATED</td><td>172.17.0.2:658018</td><td style="text-align: right;">         128</td><td style="text-align: right;">           41</td><td style="text-align: right;">           0.2</td><td style="text-align: right;">      50</td><td style="text-align: right;">          61</td><td style="text-align: right;">                 2</td><td style="text-align: right;">                2</td><td>Adam       </td><td style="text-align: right;">     1</td><td style="text-align: right;">         935.665</td><td style="text-align: right;">           0.950374</td><td style="text-align: right;">           0.94696 </td><td style="text-align: right;">           0.939652</td></tr>
# <tr><td>_Trainable_1ae0eda0</td><td>TERMINATED</td><td>172.17.0.2:658018</td><td style="text-align: right;">         128</td><td style="text-align: right;">           61</td><td style="text-align: right;">           0.2</td><td style="text-align: right;">      50</td><td style="text-align: right;">          36</td><td style="text-align: right;">                 2</td><td style="text-align: right;">                1</td><td>RMSprop    </td><td style="text-align: right;">     1</td><td style="text-align: right;">         506.378</td><td style="text-align: right;">           0.94478 </td><td style="text-align: right;">           0.964286</td><td style="text-align: right;">           0.954719</td></tr>
# <tr><td>_Trainable_203d4299</td><td>TERMINATED</td><td>172.17.0.2:658018</td><td style="text-align: right;">         128</td><td style="text-align: right;">           51</td><td style="text-align: right;">           0.2</td><td style="text-align: right;">      50</td><td style="text-align: right;">          60</td><td style="text-align: right;">                 2</td><td style="text-align: right;">                2</td><td>RMSprop    </td><td style="text-align: right;">     1</td><td style="text-align: right;">         961.194</td><td style="text-align: right;">           0.934775</td><td style="text-align: right;">           0.954215</td><td style="text-align: right;">           0.942416</td></tr>
# <tr><td>_Trainable_66aece56</td><td>TERMINATED</td><td>172.17.0.2:658018</td><td style="text-align: right;">         128</td><td style="text-align: right;">           42</td><td style="text-align: right;">           0.2</td><td style="text-align: right;">      50</td><td style="text-align: right;">          41</td><td style="text-align: right;">                 2</td><td style="text-align: right;">                2</td><td>RMSprop    </td><td style="text-align: right;">     1</td><td style="text-align: right;">        1003.13 </td><td style="text-align: right;">           0.945364</td><td style="text-align: right;">           0.958705</td><td style="text-align: right;">           0.957536</td></tr>
# <tr><td>_Trainable_258d276c</td><td>TERMINATED</td><td>172.17.0.2:658018</td><td style="text-align: right;">         128</td><td style="text-align: right;">           34</td><td style="text-align: right;">           0.2</td><td style="text-align: right;">      50</td><td style="text-align: right;">          37</td><td style="text-align: right;">                 2</td><td style="text-align: right;">                2</td><td>RMSprop    </td><td style="text-align: right;">     1</td><td style="text-align: right;">         936.25 </td><td style="text-align: right;">           0.9487  </td><td style="text-align: right;">           0.957005</td><td style="text-align: right;">           0.955251</td></tr>
# <tr><td>_Trainable_16a68049</td><td>TERMINATED</td><td>172.17.0.2:658018</td><td style="text-align: right;">         128</td><td style="text-align: right;">           37</td><td style="text-align: right;">           0.2</td><td style="text-align: right;">      50</td><td style="text-align: right;">          37</td><td style="text-align: right;">                 3</td><td style="text-align: right;">                1</td><td>RMSprop    </td><td style="text-align: right;">     1</td><td style="text-align: right;">         573.255</td><td style="text-align: right;">           0.947584</td><td style="text-align: right;">           0.967023</td><td style="text-align: right;">           0.951903</td></tr>
# <tr><td>_Trainable_67c38f35</td><td>TERMINATED</td><td>172.17.0.2:658018</td><td style="text-align: right;">         128</td><td style="text-align: right;">           60</td><td style="text-align: right;">           0.2</td><td style="text-align: right;">      50</td><td style="text-align: right;">          40</td><td style="text-align: right;">                 2</td><td style="text-align: right;">                1</td><td>RMSprop    </td><td style="text-align: right;">     1</td><td style="text-align: right;">         553.99 </td><td style="text-align: right;">           0.9487  </td><td style="text-align: right;">           0.96984 </td><td style="text-align: right;">           0.960858</td></tr>
# <tr><td>_Trainable_fa0137bc</td><td>TERMINATED</td><td>172.17.0.2:658018</td><td style="text-align: right;">         128</td><td style="text-align: right;">           56</td><td style="text-align: right;">           0.2</td><td style="text-align: right;">      50</td><td style="text-align: right;">          41</td><td style="text-align: right;">                 1</td><td style="text-align: right;">                2</td><td>SGD        </td><td style="text-align: right;">     1</td><td style="text-align: right;">        1581.95 </td><td style="text-align: right;">           0.774138</td><td style="text-align: right;">           0.787202</td><td style="text-align: right;">           0.766396</td></tr>
# <tr><td>_Trainable_9a90aacc</td><td>TERMINATED</td><td>172.17.0.2:658018</td><td style="text-align: right;">         128</td><td style="text-align: right;">           36</td><td st
# (_Trainable pid=658018) Epoch 1/50
# (_Trainable pid=658018) 27/27 - 36s - loss: 0.6617 - accuracy: 0.7729 - val_loss: 0.6351 - val_accuracy: 0.7523 - 36s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 2/50
# (_Trainable pid=658018) 27/27 - 32s - loss: 0.6088 - accuracy: 0.7775 - val_loss: 0.5984 - val_accuracy: 0.7523 - 32s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 3/50
# (_Trainable pid=658018) 27/27 - 32s - loss: 0.5761 - accuracy: 0.7775 - val_loss: 0.5778 - val_accuracy: 0.7523 - 32s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 4/50
# (_Trainable pid=658018) 27/27 - 32s - loss: 0.5586 - accuracy: 0.7775 - val_loss: 0.5670 - val_accuracy: 0.7523 - 32s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 5/50
# (_Trainable pid=658018) 27/27 - 32s - loss: 0.5490 - accuracy: 0.7775 - val_loss: 0.5622 - val_accuracy: 0.7523 - 32s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 6/50
# (_Trainable pid=658018) 27/27 - 32s - loss: 0.5405 - accuracy: 0.7775 - val_loss: 0.5602 - val_accuracy: 0.7523 - 32s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 7/50
# (_Trainable pid=658018) 27/27 - 32s - loss: 0.5382 - accuracy: 0.7775 - val_loss: 0.5597 - val_accuracy: 0.7523 - 32s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 8/50
# (_Trainable pid=658018) 27/27 - 32s - loss: 0.5356 - accuracy: 0.7775 - val_loss: 0.5598 - val_accuracy: 0.7523 - 32s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 9/50
# (_Trainable pid=658018) 27/27 - 32s - loss: 0.5389 - accuracy: 0.7775 - val_loss: 0.5600 - val_accuracy: 0.7523 - 32s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 10/50
# (_Trainable pid=658018) 27/27 - 32s - loss: 0.5346 - accuracy: 0.7775 - val_loss: 0.5603 - val_accuracy: 0.7523 - 32s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 11/50
# (_Trainable pid=658018) 27/27 - 32s - loss: 0.5365 - accuracy: 0.7775 - val_loss: 0.5605 - val_accuracy: 0.7523 - 32s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 12/50
# (_Trainable pid=658018) 27/27 - 32s - loss: 0.5365 - accuracy: 0.7775 - val_loss: 0.5606 - val_accuracy: 0.7523 - 32s/epoch - 1s/step
#  1/14 [=>............................] - ETA: 14s - loss: 0.5967 - accuracy: 0.7188
#  2/14 [===>..........................] - ETA: 5s - loss: 0.5666 - accuracy: 0.7461
#  3/14 [=====>........................] - ETA: 4s - loss: 0.5509 - accuracy: 0.7604
#  4/14 [=======>......................] - ETA: 4s - loss: 0.5472 - accuracy: 0.7637
#  5/14 [=========>....................] - ETA: 3s - loss: 0.5502 - accuracy: 0.7609
#  6/14 [===========>..................] - ETA: 3s - loss: 0.5408 - accuracy: 0.7695
#  7/14 [==============>...............] - ETA: 3s - loss: 0.5366 - accuracy: 0.7734
#  8/14 [================>.............] - ETA: 2s - loss: 0.5355 - accuracy: 0.7744
#  9/14 [==================>...........] - ETA: 2s - loss: 0.5337 - accuracy: 0.7760
# 10/14 [====================>.........] - ETA: 1s - loss: 0.5306 - accuracy: 0.7789
# 11/14 [======================>.......] - ETA: 1s - loss: 0.5264 - accuracy: 0.7827
# 12/14 [========================>.....] - ETA: 0s - loss: 0.5301 - accuracy: 0.7793
# 13/14 [==========================>...] - ETA: 0s - loss: 0.5332 - accuracy: 0.7764
# 14/14 [==============================] - 7s 433ms/step - loss: 0.5341 - accuracy: 0.7741
# (_Trainable pid=658018) Epoch 1/50
# (_Trainable pid=658018) 27/27 - 35s - loss: 0.6763 - accuracy: 0.7638 - val_loss: 0.6602 - val_accuracy: 0.7523 - 35s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 2/50
# (_Trainable pid=658018) 27/27 - 32s - loss: 0.6443 - accuracy: 0.7729 - val_loss: 0.6338 - val_accuracy: 0.7523 - 32s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 3/50
# (_Trainable pid=658018) 27/27 - 32s - loss: 0.6183 - accuracy: 0.7729 - val_loss: 0.6132 - val_accuracy: 0.7523 - 32s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 4/50
# (_Trainable pid=658018) 27/27 - 32s - loss: 0.5989 - accuracy: 0.7729 - val_loss: 0.5978 - val_accuracy: 0.7523 - 32s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 5/50
# (_Trainable pid=658018) 27/27 - 31s - loss: 0.5831 - accuracy: 0.7729 - val_loss: 0.5861 - val_accuracy: 0.7523 - 31s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 6/50
# (_Trainable pid=658018) 27/27 - 32s - loss: 0.5712 - accuracy: 0.7729 - val_loss: 0.5775 - val_accuracy: 0.7523 - 32s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 7/50
# (_Trainable pid=658018) 27/27 - 32s - loss: 0.5633 - accuracy: 0.7729 - val_loss: 0.5713 - val_accuracy: 0.7523 - 32s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 8/50
# (_Trainable pid=658018) 27/27 - 32s - loss: 0.5550 - accuracy: 0.7729 - val_loss: 0.5669 - val_accuracy: 0.7523 - 32s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 9/50
# (_Trainable pid=658018) 27/27 - 32s - loss: 0.5501 - accuracy: 0.7729 - val_loss: 0.5640 - val_accuracy: 0.7523 - 32s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 10/50
# (_Trainable pid=658018) 27/27 - 32s - loss: 0.5490 - accuracy: 0.7729 - val_loss: 0.5621 - val_accuracy: 0.7523 - 32s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 11/50
# (_Trainable pid=658018) 27/27 - 32s - loss: 0.5425 - accuracy: 0.7729 - val_loss: 0.5609 - val_accuracy: 0.7523 - 32s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 12/50
# (_Trainable pid=658018) 27/27 - 31s - loss: 0.5428 - accuracy: 0.7729 - val_loss: 0.5602 - val_accuracy: 0.7523 - 31s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 13/50
# (_Trainable pid=658018) 27/27 - 32s - loss: 0.5397 - accuracy: 0.7729 - val_loss: 0.5598 - val_accuracy: 0.7523 - 32s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 14/50
# (_Trainable pid=658018) 27/27 - 32s - loss: 0.5418 - accuracy: 0.7729 - val_loss: 0.5597 - val_accuracy: 0.7523 - 32s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 15/50
# (_Trainable pid=658018) 27/27 - 32s - loss: 0.5393 - accuracy: 0.7729 - val_loss: 0.5597 - val_accuracy: 0.7523 - 32s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 16/50
# (_Trainable pid=658018) 27/27 - 31s - loss: 0.5412 - accuracy: 0.7729 - val_loss: 0.5598 - val_accuracy: 0.7523 - 31s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 17/50
# (_Trainable pid=658018) 27/27 - 31s - loss: 0.5396 - accuracy: 0.7729 - val_loss: 0.5599 - val_accuracy: 0.7523 - 31s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 18/50
# (_Trainable pid=658018) 27/27 - 31s - loss: 0.5393 - accuracy: 0.7729 - val_loss: 0.5600 - val_accuracy: 0.7523 - 31s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 19/50
# (_Trainable pid=658018) 27/27 - 32s - loss: 0.5382 - accuracy: 0.7729 - val_loss: 0.5601 - val_accuracy: 0.7523 - 32s/epoch - 1s/step
#  1/14 [=>............................] - ETA: 14s - loss: 0.5366 - accuracy: 0.7734
#  2/14 [===>..........................] - ETA: 5s - loss: 0.5193 - accuracy: 0.7891
#  3/14 [=====>........................] - ETA: 4s - loss: 0.5365 - accuracy: 0.7734
#  4/14 [=======>......................] - ETA: 4s - loss: 0.5129 - accuracy: 0.7949
#  5/14 [=========>....................] - ETA: 3s - loss: 0.5210 - accuracy: 0.7875
#  6/14 [===========>..................] - ETA: 3s - loss: 0.5265 - accuracy: 0.7826
#  7/14 [==============>...............] - ETA: 3s - loss: 0.5279 - accuracy: 0.7812
#  8/14 [================>.............] - ETA: 2s - loss: 0.5344 - accuracy: 0.7754
#  9/14 [==================>...........] - ETA: 2s - loss: 0.5308 - accuracy: 0.7786
# 10/14 [====================>.........] - ETA: 1s - loss: 0.5305 - accuracy: 0.7789
# 11/14 [======================>.......] - ETA: 1s - loss: 0.5248 - accuracy: 0.7841
# 12/14 [========================>.....] - ETA: 0s - loss: 0.5258 - accuracy: 0.7832
# 13/14 [==========================>...] - ETA: 0s - loss: 0.5253 - accuracy: 0.7837
# 14/14 [==============================] - 7s 431ms/step - loss: 0.5239 - accuracy: 0.7872
# (_Trainable pid=658018) Epoch 1/50
# (_Trainable pid=658018) 27/27 - 34s - loss: 0.6758 - accuracy: 0.7720 - val_loss: 0.6602 - val_accuracy: 0.7523 - 34s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 2/50
# (_Trainable pid=658018) 27/27 - 32s - loss: 0.6419 - accuracy: 0.7803 - val_loss: 0.6331 - val_accuracy: 0.7523 - 32s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 3/50
# (_Trainable pid=658018) 27/27 - 32s - loss: 0.6150 - accuracy: 0.7803 - val_loss: 0.6123 - val_accuracy: 0.7523 - 32s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 4/50
# (_Trainable pid=658018) 27/27 - 32s - loss: 0.5933 - accuracy: 0.7803 - val_loss: 0.5963 - val_accuracy: 0.7523 - 32s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 5/50
# (_Trainable pid=658018) 27/27 - 31s - loss: 0.5776 - accuracy: 0.7803 - val_loss: 0.5846 - val_accuracy: 0.7523 - 31s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 6/50
# (_Trainable pid=658018) 27/27 - 31s - loss: 0.5649 - accuracy: 0.7803 - val_loss: 0.5760 - val_accuracy: 0.7523 - 31s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 7/50
# (_Trainable pid=658018) 27/27 - 32s - loss: 0.5554 - accuracy: 0.7803 - val_loss: 0.5700 - val_accuracy: 0.7523 - 32s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 8/50
# (_Trainable pid=658018) 27/27 - 31s - loss: 0.5469 - accuracy: 0.7803 - val_loss: 0.5657 - val_accuracy: 0.7523 - 31s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 9/50
# (_Trainable pid=658018) 27/27 - 31s - loss: 0.5419 - accuracy: 0.7803 - val_loss: 0.5629 - val_accuracy: 0.7523 - 31s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 10/50
# (_Trainable pid=658018) 27/27 - 31s - loss: 0.5373 - accuracy: 0.7803 - val_loss: 0.5612 - val_accuracy: 0.7523 - 31s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 11/50
# (_Trainable pid=658018) 27/27 - 32s - loss: 0.5336 - accuracy: 0.7803 - val_loss: 0.5602 - val_accuracy: 0.7523 - 32s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 12/50
# (_Trainable pid=658018) 27/27 - 31s - loss: 0.5346 - accuracy: 0.7803 - val_loss: 0.5598 - val_accuracy: 0.7523 - 31s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 13/50
# (_Trainable pid=658018) 27/27 - 31s - loss: 0.5317 - accuracy: 0.7803 - val_loss: 0.5596 - val_accuracy: 0.7523 - 31s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 14/50
# (_Trainable pid=658018) 27/27 - 31s - loss: 0.5314 - accuracy: 0.7803 - val_loss: 0.5597 - val_accuracy: 0.7523 - 31s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 15/50
# (_Trainable pid=658018) 27/27 - 31s - loss: 0.5294 - accuracy: 0.7803 - val_loss: 0.5599 - val_accuracy: 0.7523 - 31s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 16/50
# (_Trainable pid=658018) 27/27 - 32s - loss: 0.5318 - accuracy: 0.7803 - val_loss: 0.5601 - val_accuracy: 0.7523 - 32s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 17/50
# (_Trainable pid=658018) 27/27 - 31s - loss: 0.5305 - accuracy: 0.7803 - val_loss: 0.5603 - val_accuracy: 0.7523 - 31s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 18/50
# (_Trainable pid=658018) 27/27 - 31s - loss: 0.5298 - accuracy: 0.7803 - val_loss: 0.5605 - val_accuracy: 0.7523 - 31s/epoch - 1s/step
#  1/14 [=>............................] - ETA: 14s - loss: 0.5102 - accuracy: 0.7969
#  2/14 [===>..........................] - ETA: 5s - loss: 0.5405 - accuracy: 0.7695
#  3/14 [=====>........................] - ETA: 4s - loss: 0.5651 - accuracy: 0.7474
#  4/14 [=======>......................] - ETA: 4s - loss: 0.5666 - accuracy: 0.7461
#  5/14 [=========>....................] - ETA: 3s - loss: 0.5762 - accuracy: 0.7375
#  6/14 [===========>..................] - ETA: 3s - loss: 0.5681 - accuracy: 0.7448
#  7/14 [==============>...............] - ETA: 3s - loss: 0.5561 - accuracy: 0.7556
#  8/14 [================>.............] - ETA: 2s - loss: 0.5547 - accuracy: 0.7568
#  9/14 [==================>...........] - ETA: 2s - loss: 0.5498 - accuracy: 0.7613
# 10/14 [====================>.........] - ETA: 1s - loss: 0.5493 - accuracy: 0.7617
# 11/14 [======================>.......] - ETA: 1s - loss: 0.5466 - accuracy: 0.7642
# 12/14 [========================>.....] - ETA: 0s - loss: 0.5428 - accuracy: 0.7676
# 13/14 [==========================>...] - ETA: 0s - loss: 0.5377 - accuracy: 0.7722
# 14/14 [==============================] - 7s 432ms/step - loss: 0.5399 - accuracy: 0.7664
# (_Trainable pid=658018) Epoch 1/50
# (_Trainable pid=658018) 27/27 - 38s - loss: 0.5487 - accuracy: 0.7711 - val_loss: 0.4285 - val_accuracy: 0.7523 - 38s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 2/50
# (_Trainable pid=658018) 27/27 - 35s - loss: 0.2201 - accuracy: 0.8942 - val_loss: 0.2124 - val_accuracy: 0.9266 - 35s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 3/50
# (_Trainable pid=658018) 27/27 - 35s - loss: 0.0728 - accuracy: 0.9774 - val_loss: 0.1796 - val_accuracy: 0.9328 - 35s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 4/50
# (_Trainable pid=658018) 27/27 - 35s - loss: 0.0154 - accuracy: 0.9950 - val_loss: 0.1815 - val_accuracy: 0.9438 - 35s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 5/50
# (_Trainable pid=658018) 27/27 - 35s - loss: 0.0094 - accuracy: 0.9977 - val_loss: 0.2208 - val_accuracy: 0.9492 - 35s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 6/50
# (_Trainable pid=658018) 27/27 - 35s - loss: 0.0039 - accuracy: 0.9988 - val_loss: 0.2427 - val_accuracy: 0.9555 - 35s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 7/50
# (_Trainable pid=658018) 27/27 - 35s - loss: 0.0042 - accuracy: 0.9982 - val_loss: 0.2317 - val_accuracy: 0.9477 - 35s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 8/50
# (_Trainable pid=658018) 27/27 - 35s - loss: 0.0026 - accuracy: 0.9991 - val_loss: 0.2404 - val_accuracy: 0.9500 - 35s/epoch - 1s/step
#  1/14 [=>............................] - ETA: 14s - loss: 0.2245 - accuracy: 0.9297
#  2/14 [===>..........................] - ETA: 5s - loss: 0.1843 - accuracy: 0.9336
#  3/14 [=====>........................] - ETA: 4s - loss: 0.1762 - accuracy: 0.9427
#  4/14 [=======>......................] - ETA: 4s - loss: 0.1592 - accuracy: 0.9473
#  5/14 [=========>....................] - ETA: 3s - loss: 0.1469 - accuracy: 0.9516
#  6/14 [===========>..................] - ETA: 3s - loss: 0.1363 - accuracy: 0.9544
#  7/14 [==============>...............] - ETA: 3s - loss: 0.1380 - accuracy: 0.9520
#  8/14 [================>.............] - ETA: 2s - loss: 0.1501 - accuracy: 0.9502
#  9/14 [==================>...........] - ETA: 2s - loss: 0.1406 - accuracy: 0.9540
# 10/14 [====================>.........] - ETA: 1s - loss: 0.1385 - accuracy: 0.9555
# 11/14 [======================>.......] - ETA: 1s - loss: 0.1404 - accuracy: 0.9545
# 12/14 [========================>.....] - ETA: 0s - loss: 0.1400 - accuracy: 0.9544
# 13/14 [==========================>...] - ETA: 0s - loss: 0.1426 - accuracy: 0.9519
# 14/14 [==============================] - 7s 432ms/step - loss: 0.1480 - accuracy: 0.9504
# (_Trainable pid=658018) Epoch 1/50
# (_Trainable pid=658018) 27/27 - 38s - loss: 0.5505 - accuracy: 0.7706 - val_loss: 0.4332 - val_accuracy: 0.7523 - 38s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 2/50
# (_Trainable pid=658018) 27/27 - 35s - loss: 0.2677 - accuracy: 0.8816 - val_loss: 0.2492 - val_accuracy: 0.9203 - 35s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 3/50
# (_Trainable pid=658018) 27/27 - 35s - loss: 0.0695 - accuracy: 0.9842 - val_loss: 0.2477 - val_accuracy: 0.9320 - 35s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 4/50
# (_Trainable pid=658018) 27/27 - 35s - loss: 0.0258 - accuracy: 0.9941 - val_loss: 0.2138 - val_accuracy: 0.9414 - 35s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 5/50
# (_Trainable pid=658018) 27/27 - 35s - loss: 0.0065 - accuracy: 0.9982 - val_loss: 0.2447 - val_accuracy: 0.9422 - 35s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 6/50
# (_Trainable pid=658018) 27/27 - 35s - loss: 0.0087 - accuracy: 0.9974 - val_loss: 0.2368 - val_accuracy: 0.9352 - 35s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 7/50
# (_Trainable pid=658018) 27/27 - 35s - loss: 0.0050 - accuracy: 0.9982 - val_loss: 0.2577 - val_accuracy: 0.9328 - 35s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 8/50
# (_Trainable pid=658018) 27/27 - 35s - loss: 0.0023 - accuracy: 0.9991 - val_loss: 0.2883 - val_accuracy: 0.9352 - 35s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 9/50
# (_Trainable pid=658018) 27/27 - 35s - loss: 0.0016 - accuracy: 0.9994 - val_loss: 0.3100 - val_accuracy: 0.9367 - 35s/epoch - 1s/step
#  1/14 [=>............................] - ETA: 14s - loss: 0.0830 - accuracy: 0.9688
#  2/14 [===>..........................] - ETA: 5s - loss: 0.1448 - accuracy: 0.9609
#  3/14 [=====>........................] - ETA: 4s - loss: 0.1934 - accuracy: 0.9453
#  4/14 [=======>......................] - ETA: 4s - loss: 0.2064 - accuracy: 0.9453
#  5/14 [=========>....................] - ETA: 3s - loss: 0.1897 - accuracy: 0.9500
#  6/14 [===========>..................] - ETA: 3s - loss: 0.1878 - accuracy: 0.9479
#  7/14 [==============>...............] - ETA: 3s - loss: 0.1867 - accuracy: 0.9475
#  8/14 [================>.............] - ETA: 2s - loss: 0.1868 - accuracy: 0.9453
#  9/14 [==================>...........] - ETA: 2s - loss: 0.1973 - accuracy: 0.9444
# 10/14 [====================>.........] - ETA: 1s - loss: 0.1923 - accuracy: 0.9453
# 11/14 [======================>.......] - ETA: 1s - loss: 0.1944 - accuracy: 0.9446
# 12/14 [========================>.....] - ETA: 0s - loss: 0.1905 - accuracy: 0.9447
# 13/14 [==========================>...] - ETA: 0s - loss: 0.1943 - accuracy: 0.9447
# 14/14 [==============================] - 7s 431ms/step - loss: 0.1903 - accuracy: 0.9470
# (_Trainable pid=658018) Epoch 1/50
# (_Trainable pid=658018) 27/27 - 39s - loss: 0.5238 - accuracy: 0.7732 - val_loss: 0.3970 - val_accuracy: 0.7523 - 39s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 2/50
# (_Trainable pid=658018) 27/27 - 35s - loss: 0.2572 - accuracy: 0.8922 - val_loss: 0.2813 - val_accuracy: 0.9172 - 35s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 3/50
# (_Trainable pid=658018) 27/27 - 34s - loss: 0.0684 - accuracy: 0.9810 - val_loss: 0.2278 - val_accuracy: 0.9250 - 34s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 4/50
# (_Trainable pid=658018) 27/27 - 35s - loss: 0.0204 - accuracy: 0.9933 - val_loss: 0.2014 - val_accuracy: 0.9344 - 35s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 5/50
# (_Trainable pid=658018) 27/27 - 35s - loss: 0.0081 - accuracy: 0.9977 - val_loss: 0.2459 - val_accuracy: 0.9344 - 35s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 6/50
# (_Trainable pid=658018) 27/27 - 35s - loss: 0.0036 - accuracy: 0.9988 - val_loss: 0.2734 - val_accuracy: 0.9406 - 35s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 7/50
# (_Trainable pid=658018) 27/27 - 34s - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.3059 - val_accuracy: 0.9359 - 34s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 8/50
# (_Trainable pid=658018) 27/27 - 34s - loss: 0.0026 - accuracy: 0.9991 - val_loss: 0.3194 - val_accuracy: 0.9375 - 34s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 9/50
# (_Trainable pid=658018) 27/27 - 35s - loss: 0.0020 - accuracy: 0.9991 - val_loss: 0.3034 - val_accuracy: 0.9406 - 35s/epoch - 1s/step
#  1/14 [=>............................] - ETA: 14s - loss: 0.2491 - accuracy: 0.9062
#  2/14 [===>..........................] - ETA: 5s - loss: 0.1741 - accuracy: 0.9375
#  3/14 [=====>........................] - ETA: 4s - loss: 0.2094 - accuracy: 0.9271
#  4/14 [=======>......................] - ETA: 4s - loss: 0.2085 - accuracy: 0.9238
#  5/14 [=========>....................] - ETA: 3s - loss: 0.1887 - accuracy: 0.9312
#  6/14 [===========>..................] - ETA: 3s - loss: 0.1681 - accuracy: 0.9388
#  7/14 [==============>...............] - ETA: 3s - loss: 0.1826 - accuracy: 0.9353
#  8/14 [================>.............] - ETA: 2s - loss: 0.1890 - accuracy: 0.9385
#  9/14 [==================>...........] - ETA: 2s - loss: 0.1780 - accuracy: 0.9418
# 10/14 [====================>.........] - ETA: 1s - loss: 0.1764 - accuracy: 0.9422
# 11/14 [======================>.......] - ETA: 1s - loss: 0.1731 - accuracy: 0.9425
# 12/14 [========================>.....] - ETA: 0s - loss: 0.1732 - accuracy: 0.9421
# 13/14 [==========================>...] - ETA: 0s - loss: 0.1715 - accuracy: 0.9405
# 14/14 [==============================] - 7s 432ms/step - loss: 0.1751 - accuracy: 0.9397
# (_Trainable pid=658018) Epoch 1/50
# (_Trainable pid=658018) 27/27 - 20s - loss: 0.6152 - accuracy: 0.7526 - val_loss: 0.5455 - val_accuracy: 0.7523 - 20s/epoch - 731ms/step
# (_Trainable pid=658018) Epoch 2/50
# (_Trainable pid=658018) 27/27 - 18s - loss: 0.4555 - accuracy: 0.7790 - val_loss: 0.3549 - val_accuracy: 0.7922 - 18s/epoch - 649ms/step
# (_Trainable pid=658018) Epoch 3/50
# (_Trainable pid=658018) 27/27 - 18s - loss: 0.2545 - accuracy: 0.9103 - val_loss: 0.2126 - val_accuracy: 0.9266 - 18s/epoch - 651ms/step
# (_Trainable pid=658018) Epoch 4/50
# (_Trainable pid=658018) 27/27 - 18s - loss: 0.1140 - accuracy: 0.9660 - val_loss: 0.1578 - val_accuracy: 0.9391 - 18s/epoch - 650ms/step
# (_Trainable pid=658018) Epoch 5/50
# (_Trainable pid=658018) 27/27 - 17s - loss: 0.0526 - accuracy: 0.9824 - val_loss: 0.1637 - val_accuracy: 0.9430 - 17s/epoch - 647ms/step
# (_Trainable pid=658018) Epoch 6/50
# (_Trainable pid=658018) 27/27 - 17s - loss: 0.0277 - accuracy: 0.9927 - val_loss: 0.2657 - val_accuracy: 0.9328 - 17s/epoch - 646ms/step
# (_Trainable pid=658018) Epoch 7/50
# (_Trainable pid=658018) 27/27 - 17s - loss: 0.0312 - accuracy: 0.9930 - val_loss: 0.1762 - val_accuracy: 0.9484 - 17s/epoch - 647ms/step
# (_Trainable pid=658018) Epoch 8/50
# (_Trainable pid=658018) 27/27 - 18s - loss: 0.0087 - accuracy: 0.9979 - val_loss: 0.1830 - val_accuracy: 0.9469 - 18s/epoch - 650ms/step
# (_Trainable pid=658018) Epoch 9/50
# (_Trainable pid=658018) 27/27 - 18s - loss: 0.0051 - accuracy: 0.9982 - val_loss: 0.1956 - val_accuracy: 0.9508 - 18s/epoch - 651ms/step
#  1/14 [=>............................] - ETA: 9s - loss: 0.1530 - accuracy: 0.9297
#  2/14 [===>..........................] - ETA: 2s - loss: 0.1614 - accuracy: 0.9297
#  3/14 [=====>........................] - ETA: 2s - loss: 0.1712 - accuracy: 0.9297
#  4/14 [=======>......................] - ETA: 2s - loss: 0.1503 - accuracy: 0.9375
#  5/14 [=========>....................] - ETA: 1s - loss: 0.1394 - accuracy: 0.9406
#  6/14 [===========>..................] - ETA: 1s - loss: 0.1348 - accuracy: 0.9414
#  7/14 [==============>...............] - ETA: 1s - loss: 0.1346 - accuracy: 0.9431
#  8/14 [================>.............] - ETA: 1s - loss: 0.1342 - accuracy: 0.9443
#  9/14 [==================>...........] - ETA: 1s - loss: 0.1307 - accuracy: 0.9453
# 10/14 [====================>.........] - ETA: 0s - loss: 0.1311 - accuracy: 0.9461
# 11/14 [======================>.......] - ETA: 0s - loss: 0.1361 - accuracy: 0.9432
# 12/14 [========================>.....] - ETA: 0s - loss: 0.1352 - accuracy: 0.9440
# 13/14 [==========================>...] - ETA: 0s - loss: 0.1377 - accuracy: 0.9441
# 14/14 [==============================] - 4s 218ms/step - loss: 0.1391 - accuracy: 0.9448
# (_Trainable pid=658018) Epoch 1/50
# (_Trainable pid=658018) 27/27 - 20s - loss: 0.6023 - accuracy: 0.7583 - val_loss: 0.5297 - val_accuracy: 0.7523 - 20s/epoch - 723ms/step
# (_Trainable pid=658018) Epoch 2/50
# (_Trainable pid=658018) 27/27 - 17s - loss: 0.4236 - accuracy: 0.7756 - val_loss: 0.4865 - val_accuracy: 0.7883 - 17s/epoch - 644ms/step
# (_Trainable pid=658018) Epoch 3/50
# (_Trainable pid=658018) 27/27 - 18s - loss: 0.2597 - accuracy: 0.9150 - val_loss: 0.2365 - val_accuracy: 0.9133 - 18s/epoch - 649ms/step
# (_Trainable pid=658018) Epoch 4/50
# (_Trainable pid=658018) 27/27 - 17s - loss: 0.1326 - accuracy: 0.9643 - val_loss: 0.2154 - val_accuracy: 0.9117 - 17s/epoch - 643ms/step
# (_Trainable pid=658018) Epoch 5/50
# (_Trainable pid=658018) 27/27 - 17s - loss: 0.0549 - accuracy: 0.9862 - val_loss: 0.1418 - val_accuracy: 0.9477 - 17s/epoch - 645ms/step
# (_Trainable pid=658018) Epoch 6/50
# (_Trainable pid=658018) 27/27 - 17s - loss: 0.0220 - accuracy: 0.9933 - val_loss: 0.1844 - val_accuracy: 0.9430 - 17s/epoch - 647ms/step
# (_Trainable pid=658018) Epoch 7/50
# (_Trainable pid=658018) 27/27 - 18s - loss: 0.0380 - accuracy: 0.9933 - val_loss: 0.1765 - val_accuracy: 0.9445 - 18s/epoch - 649ms/step
# (_Trainable pid=658018) Epoch 8/50
# (_Trainable pid=658018) 27/27 - 17s - loss: 0.0065 - accuracy: 0.9982 - val_loss: 0.1650 - val_accuracy: 0.9539 - 17s/epoch - 646ms/step
# (_Trainable pid=658018) Epoch 9/50
# (_Trainable pid=658018) 27/27 - 17s - loss: 0.0059 - accuracy: 0.9991 - val_loss: 0.2387 - val_accuracy: 0.9438 - 17s/epoch - 646ms/step
# (_Trainable pid=658018) Epoch 10/50
# (_Trainable pid=658018) 27/27 - 17s - loss: 0.0039 - accuracy: 0.9985 - val_loss: 0.1828 - val_accuracy: 0.9555 - 17s/epoch - 640ms/step
#  1/14 [=>............................] - ETA: 8s - loss: 0.0958 - accuracy: 0.9688
#  2/14 [===>..........................] - ETA: 2s - loss: 0.1028 - accuracy: 0.9648
#  3/14 [=====>........................] - ETA: 2s - loss: 0.1088 - accuracy: 0.9583
#  4/14 [=======>......................] - ETA: 2s - loss: 0.1168 - accuracy: 0.9570
#  5/14 [=========>....................] - ETA: 1s - loss: 0.1133 - accuracy: 0.9609
#  6/14 [===========>..................] - ETA: 1s - loss: 0.1087 - accuracy: 0.9635
#  7/14 [==============>...............] - ETA: 1s - loss: 0.1075 - accuracy: 0.9621
#  8/14 [================>.............] - ETA: 1s - loss: 0.1117 - accuracy: 0.9590
#  9/14 [==================>...........] - ETA: 1s - loss: 0.1214 - accuracy: 0.9557
# 10/14 [====================>.........] - ETA: 0s - loss: 0.1164 - accuracy: 0.9570
# 11/14 [======================>.......] - ETA: 0s - loss: 0.1139 - accuracy: 0.9595
# 12/14 [========================>.....] - ETA: 0s - loss: 0.1130 - accuracy: 0.9583
# 13/14 [==========================>...] - ETA: 0s - loss: 0.1068 - accuracy: 0.9615
# 14/14 [==============================] - 4s 218ms/step - loss: 0.1049 - accuracy: 0.9643
# (_Trainable pid=658018) Epoch 1/50
# (_Trainable pid=658018) 27/27 - 20s - loss: 0.5639 - accuracy: 0.7729 - val_loss: 0.4871 - val_accuracy: 0.7523 - 20s/epoch - 741ms/step
# (_Trainable pid=658018) Epoch 2/50
# (_Trainable pid=658018) 27/27 - 17s - loss: 0.3456 - accuracy: 0.8222 - val_loss: 0.3173 - val_accuracy: 0.8672 - 17s/epoch - 641ms/step
# (_Trainable pid=658018) Epoch 3/50
# (_Trainable pid=658018) 27/27 - 17s - loss: 0.1847 - accuracy: 0.9540 - val_loss: 0.1923 - val_accuracy: 0.9430 - 17s/epoch - 639ms/step
# (_Trainable pid=658018) Epoch 4/50
# (_Trainable pid=658018) 27/27 - 17s - loss: 0.0860 - accuracy: 0.9745 - val_loss: 0.1783 - val_accuracy: 0.9406 - 17s/epoch - 633ms/step
# (_Trainable pid=658018) Epoch 5/50
# (_Trainable pid=658018) 27/27 - 17s - loss: 0.0422 - accuracy: 0.9871 - val_loss: 0.2335 - val_accuracy: 0.9383 - 17s/epoch - 641ms/step
# (_Trainable pid=658018) Epoch 6/50
# (_Trainable pid=658018) 27/27 - 17s - loss: 0.0182 - accuracy: 0.9936 - val_loss: 0.2196 - val_accuracy: 0.9516 - 17s/epoch - 628ms/step
# (_Trainable pid=658018) Epoch 7/50
# (_Trainable pid=658018) 27/27 - 17s - loss: 0.0087 - accuracy: 0.9971 - val_loss: 0.1858 - val_accuracy: 0.9531 - 17s/epoch - 635ms/step
# (_Trainable pid=658018) Epoch 8/50
# (_Trainable pid=658018) 27/27 - 17s - loss: 0.0263 - accuracy: 0.9959 - val_loss: 0.2149 - val_accuracy: 0.9391 - 17s/epoch - 643ms/step
# (_Trainable pid=658018) Epoch 9/50
# (_Trainable pid=658018) 27/27 - 17s - loss: 0.0065 - accuracy: 0.9977 - val_loss: 0.2041 - val_accuracy: 0.9547 - 17s/epoch - 627ms/step
#  1/14 [=>............................] - ETA: 9s - loss: 0.1493 - accuracy: 0.9531
#  2/14 [===>..........................] - ETA: 2s - loss: 0.1311 - accuracy: 0.9648
#  3/14 [=====>........................] - ETA: 2s - loss: 0.1680 - accuracy: 0.9453
#  4/14 [=======>......................] - ETA: 2s - loss: 0.1741 - accuracy: 0.9453
#  5/14 [=========>....................] - ETA: 1s - loss: 0.1532 - accuracy: 0.9531
#  6/14 [===========>..................] - ETA: 1s - loss: 0.1452 - accuracy: 0.9570
#  7/14 [==============>...............] - ETA: 1s - loss: 0.1411 - accuracy: 0.9587
#  8/14 [================>.............] - ETA: 1s - loss: 0.1441 - accuracy: 0.9580
#  9/14 [==================>...........] - ETA: 1s - loss: 0.1447 - accuracy: 0.9583
# 10/14 [====================>.........] - ETA: 0s - loss: 0.1368 - accuracy: 0.9609
# 11/14 [======================>.......] - ETA: 0s - loss: 0.1373 - accuracy: 0.9588
# 12/14 [========================>.....] - ETA: 0s - loss: 0.1338 - accuracy: 0.9590
# 13/14 [==========================>...] - ETA: 0s - loss: 0.1374 - accuracy: 0.9567
# 14/14 [==============================] - 4s 218ms/step - loss: 0.1411 - accuracy: 0.9547
# (_Trainable pid=658018) Epoch 1/50
# (_Trainable pid=658018) 27/27 - 37s - loss: 0.5661 - accuracy: 0.7606 - val_loss: 0.5442 - val_accuracy: 0.7523 - 37s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 2/50
# (_Trainable pid=658018) 27/27 - 33s - loss: 0.3657 - accuracy: 0.8447 - val_loss: 0.2105 - val_accuracy: 0.9242 - 33s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 3/50
# (_Trainable pid=658018) 27/27 - 34s - loss: 0.1523 - accuracy: 0.9443 - val_loss: 0.1889 - val_accuracy: 0.9258 - 34s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 4/50
# (_Trainable pid=658018) 27/27 - 33s - loss: 0.0673 - accuracy: 0.9798 - val_loss: 0.1842 - val_accuracy: 0.9289 - 33s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 5/50
# (_Trainable pid=658018) 27/27 - 33s - loss: 0.0347 - accuracy: 0.9868 - val_loss: 0.1873 - val_accuracy: 0.9508 - 33s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 6/50
# (_Trainable pid=658018) 27/27 - 33s - loss: 0.0259 - accuracy: 0.9906 - val_loss: 0.1930 - val_accuracy: 0.9453 - 33s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 7/50
# (_Trainable pid=658018) 27/27 - 33s - loss: 0.0127 - accuracy: 0.9959 - val_loss: 0.2022 - val_accuracy: 0.9531 - 33s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 8/50
# (_Trainable pid=658018) 27/27 - 33s - loss: 0.0402 - accuracy: 0.9936 - val_loss: 0.1998 - val_accuracy: 0.9500 - 33s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 9/50
# (_Trainable pid=658018) 27/27 - 33s - loss: 0.0055 - accuracy: 0.9968 - val_loss: 0.2031 - val_accuracy: 0.9516 - 33s/epoch - 1s/step
#  1/14 [=>............................] - ETA: 14s - loss: 0.1693 - accuracy: 0.9219
#  2/14 [===>..........................] - ETA: 5s - loss: 0.1553 - accuracy: 0.9375
#  3/14 [=====>........................] - ETA: 4s - loss: 0.1775 - accuracy: 0.9349
#  4/14 [=======>......................] - ETA: 4s - loss: 0.1514 - accuracy: 0.9434
#  5/14 [=========>....................] - ETA: 3s - loss: 0.1573 - accuracy: 0.9391
#  6/14 [===========>..................] - ETA: 3s - loss: 0.1619 - accuracy: 0.9375
#  7/14 [==============>...............] - ETA: 2s - loss: 0.1683 - accuracy: 0.9386
#  8/14 [================>.............] - ETA: 2s - loss: 0.1641 - accuracy: 0.9404
#  9/14 [==================>...........] - ETA: 2s - loss: 0.1599 - accuracy: 0.9427
# 10/14 [====================>.........] - ETA: 1s - loss: 0.1544 - accuracy: 0.9438
# 11/14 [======================>.......] - ETA: 1s - loss: 0.1616 - accuracy: 0.9403
# 12/14 [========================>.....] - ETA: 0s - loss: 0.1600 - accuracy: 0.9408
# 13/14 [==========================>...] - ETA: 0s - loss: 0.1653 - accuracy: 0.9387
# 14/14 [==============================] - 7s 430ms/step - loss: 0.1684 - accuracy: 0.9348
# (_Trainable pid=658018) Epoch 1/50
# (_Trainable pid=658018) 27/27 - 37s - loss: 0.5554 - accuracy: 0.7609 - val_loss: 0.4685 - val_accuracy: 0.7523 - 37s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 2/50
# (_Trainable pid=658018) 27/27 - 33s - loss: 0.3005 - accuracy: 0.8684 - val_loss: 0.2046 - val_accuracy: 0.9195 - 33s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 3/50
# (_Trainable pid=658018) 27/27 - 33s - loss: 0.1097 - accuracy: 0.9645 - val_loss: 0.2256 - val_accuracy: 0.9219 - 33s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 4/50
# (_Trainable pid=658018) 27/27 - 33s - loss: 0.0797 - accuracy: 0.9780 - val_loss: 0.1667 - val_accuracy: 0.9445 - 33s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 5/50
# (_Trainable pid=658018) 27/27 - 33s - loss: 0.0182 - accuracy: 0.9947 - val_loss: 0.2005 - val_accuracy: 0.9461 - 33s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 6/50
# (_Trainable pid=658018) 27/27 - 33s - loss: 0.0250 - accuracy: 0.9930 - val_loss: 0.2192 - val_accuracy: 0.9461 - 33s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 7/50
# (_Trainable pid=658018) 27/27 - 33s - loss: 0.0089 - accuracy: 0.9977 - val_loss: 0.2490 - val_accuracy: 0.9422 - 33s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 8/50
# (_Trainable pid=658018) 27/27 - 33s - loss: 0.0043 - accuracy: 0.9982 - val_loss: 0.2793 - val_accuracy: 0.9430 - 33s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 9/50
# (_Trainable pid=658018) 27/27 - 33s - loss: 0.0190 - accuracy: 0.9959 - val_loss: 0.2916 - val_accuracy: 0.9453 - 33s/epoch - 1s/step
#  1/14 [=>............................] - ETA: 14s - loss: 0.1213 - accuracy: 0.9688
#  2/14 [===>..........................] - ETA: 5s - loss: 0.1625 - accuracy: 0.9453
#  3/14 [=====>........................] - ETA: 4s - loss: 0.1661 - accuracy: 0.9479
#  4/14 [=======>......................] - ETA: 4s - loss: 0.1639 - accuracy: 0.9492
#  5/14 [=========>....................] - ETA: 3s - loss: 0.1475 - accuracy: 0.9516
#  6/14 [===========>..................] - ETA: 3s - loss: 0.1392 - accuracy: 0.9505
#  7/14 [==============>...............] - ETA: 3s - loss: 0.1346 - accuracy: 0.9531
#  8/14 [================>.............] - ETA: 2s - loss: 0.1391 - accuracy: 0.9512
#  9/14 [==================>...........] - ETA: 2s - loss: 0.1539 - accuracy: 0.9479
# 10/14 [====================>.........] - ETA: 1s - loss: 0.1476 - accuracy: 0.9492
# 11/14 [======================>.......] - ETA: 1s - loss: 0.1473 - accuracy: 0.9489
# 12/14 [========================>.....] - ETA: 0s - loss: 0.1454 - accuracy: 0.9499
# 13/14 [==========================>...] - ETA: 0s - loss: 0.1389 - accuracy: 0.9525
# 14/14 [==============================] - 7s 431ms/step - loss: 0.1370 - accuracy: 0.9542
# (_Trainable pid=658018) Epoch 1/50
# (_Trainable pid=658018) 27/27 - 36s - loss: 0.5316 - accuracy: 0.7744 - val_loss: 0.4335 - val_accuracy: 0.7531 - 36s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 2/50
# (_Trainable pid=658018) 27/27 - 33s - loss: 0.2813 - accuracy: 0.8869 - val_loss: 0.2343 - val_accuracy: 0.9070 - 33s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 3/50
# (_Trainable pid=658018) 27/27 - 33s - loss: 0.1183 - accuracy: 0.9590 - val_loss: 0.1836 - val_accuracy: 0.9398 - 33s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 4/50
# (_Trainable pid=658018) 27/27 - 33s - loss: 0.0681 - accuracy: 0.9769 - val_loss: 0.2597 - val_accuracy: 0.9320 - 33s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 5/50
# (_Trainable pid=658018) 27/27 - 33s - loss: 0.0426 - accuracy: 0.9865 - val_loss: 0.1767 - val_accuracy: 0.9359 - 33s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 6/50
# (_Trainable pid=658018) 27/27 - 33s - loss: 0.0229 - accuracy: 0.9921 - val_loss: 0.1818 - val_accuracy: 0.9391 - 33s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 7/50
# (_Trainable pid=658018) 27/27 - 33s - loss: 0.0104 - accuracy: 0.9953 - val_loss: 0.1996 - val_accuracy: 0.9398 - 33s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 8/50
# (_Trainable pid=658018) 27/27 - 33s - loss: 0.0087 - accuracy: 0.9962 - val_loss: 0.2511 - val_accuracy: 0.9336 - 33s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 9/50
# (_Trainable pid=658018) 27/27 - 33s - loss: 0.0113 - accuracy: 0.9968 - val_loss: 0.3082 - val_accuracy: 0.9336 - 33s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 10/50
# (_Trainable pid=658018) 27/27 - 33s - loss: 0.0044 - accuracy: 0.9985 - val_loss: 0.2577 - val_accuracy: 0.9477 - 33s/epoch - 1s/step
#  1/14 [=>............................] - ETA: 14s - loss: 0.1948 - accuracy: 0.9141
#  2/14 [===>..........................] - ETA: 5s - loss: 0.1488 - accuracy: 0.9414
#  3/14 [=====>........................] - ETA: 4s - loss: 0.1615 - accuracy: 0.9323
#  4/14 [=======>......................] - ETA: 4s - loss: 0.1592 - accuracy: 0.9375
#  5/14 [=========>....................] - ETA: 3s - loss: 0.1460 - accuracy: 0.9438
#  6/14 [===========>..................] - ETA: 3s - loss: 0.1386 - accuracy: 0.9466
#  7/14 [==============>...............] - ETA: 3s - loss: 0.1428 - accuracy: 0.9431
#  8/14 [================>.............] - ETA: 2s - loss: 0.1423 - accuracy: 0.9443
#  9/14 [==================>...........] - ETA: 2s - loss: 0.1437 - accuracy: 0.9444
# 10/14 [====================>.........] - ETA: 1s - loss: 0.1366 - accuracy: 0.9477
# 11/14 [======================>.......] - ETA: 1s - loss: 0.1369 - accuracy: 0.9460
# 12/14 [========================>.....] - ETA: 0s - loss: 0.1366 - accuracy: 0.9466
# 13/14 [==========================>...] - ETA: 0s - loss: 0.1397 - accuracy: 0.9453
# 14/14 [==============================] - 7s 431ms/step - loss: 0.1434 - accuracy: 0.9424
# (_Trainable pid=658018) Epoch 1/50
# (_Trainable pid=658018) 27/27 - 35s - loss: 0.5521 - accuracy: 0.7655 - val_loss: 0.4885 - val_accuracy: 0.7523 - 35s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 2/50
# (_Trainable pid=658018) 27/27 - 31s - loss: 0.3055 - accuracy: 0.8772 - val_loss: 0.2311 - val_accuracy: 0.9094 - 31s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 3/50
# (_Trainable pid=658018) 27/27 - 31s - loss: 0.1231 - accuracy: 0.9622 - val_loss: 0.5109 - val_accuracy: 0.9047 - 31s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 4/50
# (_Trainable pid=658018) 27/27 - 32s - loss: 0.0617 - accuracy: 0.9804 - val_loss: 0.2139 - val_accuracy: 0.9383 - 32s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 5/50
# (_Trainable pid=658018) 27/27 - 32s - loss: 0.0293 - accuracy: 0.9900 - val_loss: 0.1859 - val_accuracy: 0.9484 - 32s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 6/50
# (_Trainable pid=658018) 27/27 - 31s - loss: 0.0173 - accuracy: 0.9938 - val_loss: 0.1913 - val_accuracy: 0.9406 - 31s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 7/50
# (_Trainable pid=658018) 27/27 - 31s - loss: 0.0180 - accuracy: 0.9956 - val_loss: 0.2043 - val_accuracy: 0.9523 - 31s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 8/50
# (_Trainable pid=658018) 27/27 - 31s - loss: 0.0101 - accuracy: 0.9968 - val_loss: 0.2501 - val_accuracy: 0.9398 - 31s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 9/50
# (_Trainable pid=658018) 27/27 - 31s - loss: 0.0037 - accuracy: 0.9985 - val_loss: 0.2330 - val_accuracy: 0.9492 - 31s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 10/50
# (_Trainable pid=658018) 27/27 - 31s - loss: 0.0033 - accuracy: 0.9985 - val_loss: 0.2657 - val_accuracy: 0.9516 - 31s/epoch - 1s/step
#  1/14 [=>............................] - ETA: 14s - loss: 0.1900 - accuracy: 0.9453
#  2/14 [===>..........................] - ETA: 5s - loss: 0.1595 - accuracy: 0.9531
#  3/14 [=====>........................] - ETA: 4s - loss: 0.1765 - accuracy: 0.9583
#  4/14 [=======>......................] - ETA: 4s - loss: 0.1520 - accuracy: 0.9609
#  5/14 [=========>....................] - ETA: 3s - loss: 0.1546 - accuracy: 0.9578
#  6/14 [===========>..................] - ETA: 3s - loss: 0.1484 - accuracy: 0.9596
#  7/14 [==============>...............] - ETA: 2s - loss: 0.1480 - accuracy: 0.9587
#  8/14 [================>.............] - ETA: 2s - loss: 0.1602 - accuracy: 0.9531
#  9/14 [==================>...........] - ETA: 2s - loss: 0.1568 - accuracy: 0.9497
# 10/14 [====================>.........] - ETA: 1s - loss: 0.1534 - accuracy: 0.9523
# 11/14 [======================>.......] - ETA: 1s - loss: 0.1518 - accuracy: 0.9524
# 12/14 [========================>.....] - ETA: 0s - loss: 0.1514 - accuracy: 0.9531
# 13/14 [==========================>...] - ETA: 0s - loss: 0.1636 - accuracy: 0.9483
# 14/14 [==============================] - ETA: 0s - loss: 0.1677 - accuracy: 0.9454
# 14/14 [==============================] - 7s 422ms/step - loss: 0.1677 - accuracy: 0.9454
# (_Trainable pid=658018) Epoch 1/50
# (_Trainable pid=658018) 27/27 - 35s - loss: 0.5860 - accuracy: 0.7565 - val_loss: 0.5367 - val_accuracy: 0.7523 - 35s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 2/50
# (_Trainable pid=658018) 27/27 - 31s - loss: 0.3949 - accuracy: 0.8268 - val_loss: 0.2692 - val_accuracy: 0.9000 - 31s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 3/50
# (_Trainable pid=658018) 27/27 - 31s - loss: 0.1749 - accuracy: 0.9399 - val_loss: 0.1642 - val_accuracy: 0.9438 - 31s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 4/50
# (_Trainable pid=658018) 27/27 - 31s - loss: 0.0746 - accuracy: 0.9760 - val_loss: 0.1856 - val_accuracy: 0.9328 - 31s/epoch - 1s/step
# (_Trainable pid=658018) Epoch 5/50
# ...
# (_Trainable pid=658018) Epoch 4/50
# (_Trainable pid=658018) 27/27 - 16s - loss: 0.1642 - accuracy: 0.9707 - val_loss: 0.2038 - val_accuracy: 0.9484 - 16s/epoch - 608ms/step
# (_Trainable pid=658018) Epoch 5/50
# (_Trainable pid=658018) 27/27 - 17s - loss: 0.0921 - accuracy: 0.9783 - val_loss: 0.1892 - val_accuracy: 0.9422 - 17s/epoch - 618ms/step
# (_Trainable pid=658018) Epoch 6/50
# (_Trainable pid=658018) 27/27 - 17s - loss: 0.0712 - accuracy: 0.9795 - val_loss: 0.1782 - val_accuracy: 0.9414 - 17s/epoch - 616ms/step
# (_Trainable pid=658018) Epoch 7/50
# (_Trainable pid=658018) 27/27 - 17s - loss: 0.0254 - accuracy: 0.9927 - val_loss: 0.1789 - val_accuracy: 0.9445 - 17s/epoch - 613ms/step
# (_Trainable pid=658018) Epoch 8/50
# (_Trainable pid=658018) 27/27 - 16s - loss: 0.0158 - accuracy: 0.9950 - val_loss: 0.2048 - val_accuracy: 0.9422 - 16s/epoch - 610ms/step
# (_Trainable pid=658018) Epoch 9/50
# (_Trainable pid=658018) 27/27 - 17s - loss: 0.0087 - accuracy: 0.9977 - val_loss: 0.2374 - val_accuracy: 0.9391 - 17s/epoch - 620ms/step
# (_Trainable pid=658018) Epoch 10/50
# (_Trainable pid=658018) 27/27 - 17s - loss: 0.0042 - accuracy: 0.9985 - val_loss: 0.6983 - val_accuracy: 0.9195 - 17s/epoch - 615ms/step
# (_Trainable pid=658018) Epoch 11/50
# (_Trainable pid=658018) 27/27 - 16s - loss: 0.0084 - accuracy: 0.9974 - val_loss: 0.2125 - val_accuracy: 0.9516 - 16s/epoch - 608ms/step
#  1/14 [=>............................] - ETA: 9s - loss: 0.1870 - accuracy: 0.9219
#  2/14 [===>..........................] - ETA: 2s - loss: 0.1221 - accuracy: 0.9531
#  3/14 [=====>........................] - ETA: 2s - loss: 0.1549 - accuracy: 0.9427
#  4/14 [=======>......................] - ETA: 2s - loss: 0.1627 - accuracy: 0.9414
#  5/14 [=========>....................] - ETA: 1s - loss: 0.1458 - accuracy: 0.9484
#  6/14 [===========>..................] - ETA: 1s - loss: 0.1418 - accuracy: 0.9505
#  7/14 [==============>...............] - ETA: 1s - loss: 0.1408 - accuracy: 0.9509
#  8/14 [================>.............] - ETA: 1s - loss: 0.1406 - accuracy: 0.9531
#  9/14 [==================>...........] - ETA: 1s - loss: 0.1385 - accuracy: 0.9549
# 10/14 [====================>.........] - ETA: 0s - loss: 0.1329 - accuracy: 0.9563
# 11/14 [======================>.......] - ETA: 0s - loss: 0.1329 - accuracy: 0.9538
# 12/14 [========================>.....] - ETA: 0s - loss: 0.1302 - accuracy: 0.9551
# 13/14 [==========================>...] - ETA: 0s - loss: 0.1302 - accuracy: 0.9555
# 14/14 [==============================] - 3s 213ms/step - loss: 0.1332 - accuracy: 0.9485
# 2023-05-26 15:04:08,227	INFO tune.py:945 -- Total run time: 9200.96 seconds (9200.93 seconds for the tuning loop).
# 2023-05-26 15:04:08.289878: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:736] failed to allocate 21.15GiB (22708420608 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-05-26 15:04:08.290484: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:736] failed to allocate 19.03GiB (20437577728 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-05-26 15:04:08.291059: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:736] failed to allocate 17.13GiB (18393819136 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-05-26 15:04:08.291693: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:736] failed to allocate 15.42GiB (16554436608 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-05-26 15:04:08.292291: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:736] failed to allocate 13.88GiB (14898992128 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-05-26 15:04:08.292859: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:736] failed to allocate 12.49GiB (13409092608 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-05-26 15:04:08.293427: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:736] failed to allocate 11.24GiB (12068183040 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-05-26 15:04:08.294016: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:736] failed to allocate 10.12GiB (10861364224 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-05-26 15:04:08.294589: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:736] failed to allocate 9.10GiB (9775227904 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-05-26 15:04:08.295199: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:736] failed to allocate 8.19GiB (8797705216 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-05-26 15:04:08.295768: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:736] failed to allocate 7.37GiB (7917934592 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-05-26 15:04:08.296334: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:736] failed to allocate 6.64GiB (7126140928 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-05-26 15:04:08.296900: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:736] failed to allocate 5.97GiB (6413526528 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-05-26 15:04:08.297465: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:736] failed to allocate 5.38GiB (5772173824 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-05-26 15:04:08.298066: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:736] failed to allocate 4.84GiB (5194956288 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-05-26 15:04:08.298639: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:736] failed to allocate 4.35GiB (4675460608 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-05-26 15:04:08.299212: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:736] failed to allocate 3.92GiB (4207914496 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-05-26 15:04:08.299778: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:736] failed to allocate 3.53GiB (3787122944 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-05-26 15:04:08.300343: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:736] failed to allocate 3.17GiB (3408410624 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-05-26 15:04:08.300919: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:736] failed to allocate 2.86GiB (3067569408 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-05-26 15:04:08.301498: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:736] failed to allocate 2.57GiB (2760812288 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-05-26 15:04:08.302083: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:736] failed to allocate 2.31GiB (2484730880 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-05-26 15:04:08.302653: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:736] failed to allocate 2.08GiB (2236257792 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-05-26 15:04:08.303219: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:736] failed to allocate 1.87GiB (2012632064 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-05-26 15:04:08.303783: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:736] failed to allocate 1.69GiB (1811368960 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-05-26 15:04:08.304347: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:736] failed to allocate 1.52GiB (1630232064 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-05-26 15:04:08.304921: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:736] failed to allocate 1.37GiB (1467208960 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-05-26 15:04:08.305492: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:736] failed to allocate 1.23GiB (1320488192 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-05-26 15:04:08.306082: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:736] failed to allocate 1.11GiB (1188439296 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-05-26 15:04:08.306666: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:736] failed to allocate 1020.04MiB (1069595392 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-05-26 15:04:08.307239: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:736] failed to allocate 918.04MiB (962636032 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-05-26 15:04:08.307810: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:736] failed to allocate 826.24MiB (866372608 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-05-26 15:04:08.519830: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 15:04:08.521259: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 15:04:08.522735: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Epoch 1/50
# 2023-05-26 15:04:09.134734: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 15:04:09.136162: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 15:04:09.137211: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-26 15:04:09.808668: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 15:04:09.810136: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 15:04:09.811177: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-26 15:04:11.460226: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-05-26 15:04:11.775197: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-05-26 15:04:11.779393: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7f181c0b1a60 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-05-26 15:04:11.779425: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2023-05-26 15:04:11.783588: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-05-26 15:04:11.898760: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2023-05-26 15:04:35.369792: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 15:04:35.371157: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 15:04:35.372158: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 40/40 - 29s - loss: 0.5184 - accuracy: 0.7720 - val_loss: 0.4564 - val_accuracy: 0.7523 - 29s/epoch - 720ms/step
# Epoch 2/50
# 40/40 - 25s - loss: 0.2492 - accuracy: 0.9033 - val_loss: 0.3143 - val_accuracy: 0.9148 - 25s/epoch - 628ms/step
# Epoch 3/50
# 40/40 - 25s - loss: 0.0981 - accuracy: 0.9705 - val_loss: 0.1338 - val_accuracy: 0.9547 - 25s/epoch - 627ms/step
# Epoch 4/50
# 40/40 - 25s - loss: 0.0434 - accuracy: 0.9865 - val_loss: 0.1142 - val_accuracy: 0.9633 - 25s/epoch - 620ms/step
# Epoch 5/50
# 40/40 - 25s - loss: 0.0215 - accuracy: 0.9939 - val_loss: 0.1787 - val_accuracy: 0.9516 - 25s/epoch - 620ms/step
# Epoch 6/50
# 40/40 - 25s - loss: 0.0103 - accuracy: 0.9967 - val_loss: 0.1464 - val_accuracy: 0.9664 - 25s/epoch - 625ms/step
# Epoch 7/50
# 40/40 - 25s - loss: 0.0106 - accuracy: 0.9967 - val_loss: 0.1761 - val_accuracy: 0.9523 - 25s/epoch - 626ms/step
# Epoch 8/50
# 40/40 - 25s - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.1623 - val_accuracy: 0.9625 - 25s/epoch - 625ms/step
# Epoch 9/50
# 40/40 - 25s - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.1852 - val_accuracy: 0.9594 - 25s/epoch - 627ms/step
# Best parameter combination:  {'optimizer': 'RMSprop', 'num_lstm_layers': 1, 'lstm_units': 40, 'num_dense_layers': 2, 'dense_units': 60, 'dropout_rate': 0.2, 'batch_size': 128, 'epochs': 50}
# Best score:  0.9597989916801453

# %%
# Get the best model
best_model = tune_search.best_estimator_.model

# Evaluate the best model
loss, accuracy = best_model.evaluate(X_test, y_test)

print('Test score:', loss)
print('Test accuracy:', accuracy)

# Save the best model
best_model.save('model_final_gridsearch.h5')
# Out:
# 2023-05-26 15:07:58.060129: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 15:07:58.061471: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 15:07:58.062475: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 40/40 [==============================] - 9s 215ms/step - loss: 0.1142 - accuracy: 0.9633
# Test score: 0.11415628343820572
# Test accuracy: 0.9632812738418579

# %%
import json
import pprint

base_directory = 'ray_results'

# Directories of interest
dirs_of_interest = ['_Trainable_2023-05-26_12-30-47']

pp = pprint.PrettyPrinter(indent=4)

for dir_of_interest in dirs_of_interest:
    dirpath = os.path.join(base_directory, dir_of_interest)

    for subdir in os.listdir(dirpath):
        subdir_path = os.path.join(dirpath, subdir)

        # Continue to the next subdir if it's not a directory or does not contain both 'params.json' and 'result.json'
        if not os.path.isdir(subdir_path) or 'params.json' not in os.listdir(subdir_path) or 'result.json' not in os.listdir(subdir_path):
            continue

        with open(os.path.join(subdir_path, 'params.json')) as f:
            params = json.load(f)

        with open(os.path.join(subdir_path, 'result.json')) as f:
            if os.stat(os.path.join(subdir_path, 'result.json')).st_size != 0:
                results = json.load(f)
            else:
                print(f"Empty 'result.json' file in: {os.path.join(subdir_path, 'result.json')}")
                continue

        scores = [value for value in results.values() if isinstance(value, (int, float))]
        if scores:
            mean_score = np.mean(scores)
            std_score = np.std(scores)
            print(f"Avg mean test score: {mean_score}, Std test score: {std_score}\nParameters:")
            pp.pprint(params)
            print("\n---\n")
        else:
            print(f"No numeric scores found in: {os.path.join(subdir_path, 'result.json')}")
# Out:
# Avg mean test score: 129674507.19802794, Std test score: 449014380.41675013
# Parameters:
# {   'batch_size': 128,
#     'cv': 'KFold(n_splits=3, random_state=None, shuffle=False)',
#     'dense_units': 36,
#     'dropout_rate': 0.2,
#     'early_stop_type': 'EarlyStopping.NO_EARLY_STOP',
#     'early_stopping': False,
#     'epochs': 50,
#     'groups': None,
#     'lstm_units': 52,
#     'max_iters': 1,
#     'metric_name': 'average_test_score',
#     'n_jobs': 1,
#     'num_dense_layers': 3,
#     'num_lstm_layers': 2,
#     'optimizer': 'SGD',
#     'return_train_score': False,
#     'scoring': {'score': '<function _passthrough_scorer at 0x7f229c38cee0>'}}
#
# ---
#
# Avg mean test score: 129674430.6709668, Std test score: 449014672.7259403
# Parameters:
# {   'batch_size': 128,
#     'cv': 'KFold(n_splits=3, random_state=None, shuffle=False)',
#     'dense_units': 41,
#     'dropout_rate': 0.2,
#     'early_stop_type': 'EarlyStopping.NO_EARLY_STOP',
#     'early_stopping': False,
#     'epochs': 50,
#     'groups': None,
#     'lstm_units': 61,
#     'max_iters': 1,
#     'metric_name': 'average_test_score',
#     'n_jobs': 1,
#     'num_dense_layers': 2,
#     'num_lstm_layers': 2,
#     'optimizer': 'Adam',
#     'return_train_score': False,
#     'scoring': {'score': '<function _passthrough_scorer at 0x7f229c38cee0>'}}
#
# ---
#
# Avg mean test score: 129674370.53133869, Std test score: 449014836.16833985
# Parameters:
# {   'batch_size': 128,
#     'cv': 'KFold(n_splits=3, random_state=None, shuffle=False)',
#     'dense_units': 61,
#     'dropout_rate': 0.2,
#     'early_stop_type': 'EarlyStopping.NO_EARLY_STOP',
#     'early_stopping': False,
#     'epochs': 50,
#     'groups': None,
#     'lstm_units': 36,
#     'max_iters': 1,
#     'metric_name': 'average_test_score',
#     'n_jobs': 1,
#     'num_dense_layers': 2,
#     'num_lstm_layers': 1,
#     'optimizer': 'RMSprop',
#     'return_train_score': False,
#     'scoring': {'score': '<function _passthrough_scorer at 0x7f229c38cee0>'}}
#
# ---
#
# Avg mean test score: 129674549.4078673, Std test score: 449015061.93523234
# Parameters:
# {   'batch_size': 128,
#     'cv': 'KFold(n_splits=3, random_state=None, shuffle=False)',
#     'dense_units': 51,
#     'dropout_rate': 0.2,
#     'early_stop_type': 'EarlyStopping.NO_EARLY_STOP',
#     'early_stopping': False,
#     'epochs': 50,
#     'groups': None,
#     'lstm_units': 60,
#     'max_iters': 1,
#     'metric_name': 'average_test_score',
#     'n_jobs': 1,
#     'num_dense_layers': 2,
#     'num_lstm_layers': 2,
#     'optimizer': 'RMSprop',
#     'return_train_score': False,
#     'scoring': {'score': '<function _passthrough_scorer at 0x7f229c38cee0>'}}
#
# ---
#
# Avg mean test score: 129674636.24306989, Std test score: 449015326.4080422
# Parameters:
# {   'batch_size': 128,
#     'cv': 'KFold(n_splits=3, random_state=None, shuffle=False)',
#     'dense_units': 42,
#     'dropout_rate': 0.2,
#     'early_stop_type': 'EarlyStopping.NO_EARLY_STOP',
#     'early_stopping': False,
#     'epochs': 50,
#     'groups': None,
#     'lstm_units': 41,
#     'max_iters': 1,
#     'metric_name': 'average_test_score',
#     'n_jobs': 1,
#     'num_dense_layers': 2,
#     'num_lstm_layers': 2,
#     'optimizer': 'RMSprop',
#     'return_train_score': False,
#     'scoring': {'score': '<function _passthrough_scorer at 0x7f229c38cee0>'}}
#
# ---
#
# Avg mean test score: 129674692.88598655, Std test score: 449015580.5470823
# Parameters:
# {   'batch_size': 128,
#     'cv': 'KFold(n_splits=3, random_state=None, shuffle=False)',
#     'dense_units': 34,
#     'dropout_rate': 0.2,
#     'early_stop_type': 'EarlyStopping.NO_EARLY_STOP',
#     'early_stopping': False,
#     'epochs': 50,
#     'groups': None,
#     'lstm_units': 37,
#     'max_iters': 1,
#     'metric_name': 'average_test_score',
#     'n_jobs': 1,
#     'num_dense_layers': 2,
#     'num_lstm_layers': 2,
#     'optimizer': 'RMSprop',
#     'return_train_score': False,
#     'scoring': {'score': '<function _passthrough_scorer at 0x7f229c38cee0>'}}
#
# ---
#
# Avg mean test score: 129674653.19564673, Std test score: 449015757.42565966
# Parameters:
# {   'batch_size': 128,
#     'cv': 'KFold(n_splits=3, random_state=None, shuffle=False)',
#     'dense_units': 37,
#     'dropout_rate': 0.2,
#     'early_stop_type': 'EarlyStopping.NO_EARLY_STOP',
#     'early_stopping': False,
#     'epochs': 50,
#     'groups': None,
#     'lstm_units': 37,
#     'max_iters': 1,
#     'metric_name': 'average_test_score',
#     'n_jobs': 1,
#     'num_dense_layers': 3,
#     'num_lstm_layers': 1,
#     'optimizer': 'RMSprop',
#     'return_train_score': False,
#     'scoring': {'score': '<function _passthrough_scorer at 0x7f229c38cee0>'}}
#
# ---
#
# Avg mean test score: 129674691.3667414, Std test score: 449015906.3331655
# Parameters:
# {   'batch_size': 128,
#     'cv': 'KFold(n_splits=3, random_state=None, shuffle=False)',
#     'dense_units': 60,
#     'dropout_rate': 0.2,
#     'early_stop_type': 'EarlyStopping.NO_EARLY_STOP',
#     'early_stopping': False,
#     'epochs': 50,
#     'groups': None,
#     'lstm_units': 40,
#     'max_iters': 1,
#     'metric_name': 'average_test_score',
#     'n_jobs': 1,
#     'num_dense_layers': 2,
#     'num_lstm_layers': 1,
#     'optimizer': 'RMSprop',
#     'return_train_score': False,
#     'scoring': {'score': '<function _passthrough_scorer at 0x7f229c38cee0>'}}
#
# ---
#
# Avg mean test score: 129675050.21046567, Std test score: 449016259.39940286
# Parameters:
# {   'batch_size': 128,
#     'cv': 'KFold(n_splits=3, random_state=None, shuffle=False)',
#     'dense_units': 56,
#     'dropout_rate': 0.2,
#     'early_stop_type': 'EarlyStopping.NO_EARLY_STOP',
#     'early_stopping': False,
#     'epochs': 50,
#     'groups': None,
#     'lstm_units': 41,
#     'max_iters': 1,
#     'metric_name': 'average_test_score',
#     'n_jobs': 1,
#     'num_dense_layers': 1,
#     'num_lstm_layers': 2,
#     'optimizer': 'SGD',
#     'return_train_score': False,
#     'scoring': {'score': '<function _passthrough_scorer at 0x7f229c38cee0>'}}
#
# ---
#
# Avg mean test score: 129674859.17143224, Std test score: 449016477.67727345
# Parameters:
# {   'batch_size': 128,
#     'cv': 'KFold(n_splits=3, random_state=None, shuffle=False)',
#     'dense_units': 36,
#     'dropout_rate': 0.2,
#     'early_stop_type': 'EarlyStopping.NO_EARLY_STOP',
#     'early_stopping': False,
#     'epochs': 50,
#     'groups': None,
#     'lstm_units': 42,
#     'max_iters': 1,
#     'metric_name': 'average_test_score',
#     'n_jobs': 1,
#     'num_dense_layers': 2,
#     'num_lstm_layers': 1,
#     'optimizer': 'RMSprop',
#     'return_train_score': False,
#     'scoring': {'score': '<function _passthrough_scorer at 0x7f229c38cee0>'}}
#
# ---

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.model_selection import learning_curve    

# Evaluate the best model
score, acc = best_model.evaluate(X_test, y_test)

print('Test score:', score)
print('Test accuracy:', acc)

# Predictions
predictions = (best_model.predict(X_test) > 0.5).astype('int32')

# Confusion matrix
conf_matrix = confusion_matrix(y_test, predictions)

# Plotting Confusion Matrix
sns.heatmap(conf_matrix, annot=True, fmt="d")
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# Classification report
print(classification_report(y_test, predictions))

# ROC Curve and AUC for the test set
fpr, tpr, thresholds = roc_curve(y_test, predictions)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=1, label='ROC curve ( = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

## Precision-Recall Curve
precision, recall, thresholds = precision_recall_curve(y_test, predictions)
plt.plot(recall, precision, color='blue', label='Precision-Recall curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower right")
plt.show()

## Learning Curve comment as model don't have a score
# train_sizes, train_scores, test_scores = learning_curve(best_model, X_train, y_train, cv=5)
# train_scores_mean = np.mean(train_scores, axis=1)
# train_scores_std = np.std(train_scores, axis=1)
# test_scores_mean = np.mean(test_scores, axis=1)
# test_scores_std = np.std(test_scores, axis=1)
# plt.figure()
# plt.title("Learning Curve")
# plt.xlabel("Training Examples")
# plt.ylabel("Score")
# plt.ylim((0.0, 1.1))
# plt.plot(train_sizes, train_scores_mean, 'o-', color="r", label="Training score")
# plt.plot(train_sizes, test_scores_mean, 'o-', color="g", label="Cross-validation score")
# plt.fill_between(train_sizes, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.1, color="r")
# plt.fill_between(train_sizes, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, alpha=0.1, color="g")
# plt.legend(loc="best")
# plt.show()

## Validation set
# Evaluate the model on the validation data
val_score, val_acc = best_model.evaluate(data_val, df_val['label'])

print('Validation score:', val_score)
print('Validation accuracy:', val_acc)

# Predictions on the validation data
val_predictions = (best_model.predict(data_val) > 0.5).astype('int32')

# Confusion matrix for validation data
conf_matrix_val = confusion_matrix(df_val['label'], val_predictions)

# Plotting Confusion Matrix for validation data
sns.heatmap(conf_matrix_val, annot=True, fmt="d")
plt.title("Confusion Matrix for Validation Data")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# Classification report for validation data
print(classification_report(df_val['label'], val_predictions))

# ROC Curve and AUC for the validation data
fpr_val, tpr_val, thresholds_val = roc_curve(df_val['label'], val_predictions)
roc_auc_val = auc(fpr_val, tpr_val)

plt.figure()
plt.plot(fpr_val, tpr_val, color='darkorange', lw=1, label='ROC curve (area = %0.2f)' % roc_auc_val)
plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic for Validation Data')
plt.legend(loc="lower right")
plt.show()

## Precision-Recall Curve for validation data
precision_val, recall_val, thresholds_val = precision_recall_curve(df_val['label'], val_predictions)
plt.plot(recall_val, precision_val, color='blue', label='Precision-Recall curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve for Validation Data')
plt.legend(loc="lower right")
plt.show()

## Confusion Matrix Heatmap for validation data
sns.heatmap(conf_matrix_val, annot=True, fmt="d")
plt.title("Confusion Matrix for Validation Data")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
# Out:
# 40/40 [==============================] - 9s 215ms/step - loss: 0.1142 - accuracy: 0.9633
# Test score: 0.11415628343820572
# Test accuracy: 0.9632812738418579
# 2023-05-26 15:08:15.910499: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 15:08:15.911870: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 15:08:15.912876: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 40/40 [==============================] - 9s 212ms/step
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98       963
#            1       0.93      0.92      0.93       317
#
#     accuracy                           0.96      1280
#    macro avg       0.95      0.95      0.95      1280
# weighted avg       0.96      0.96      0.96      1280
# 82/82 [==============================] - 18s 214ms/step - loss: 0.3353 - accuracy: 0.8975
# Validation score: 0.3352847099304199
# Validation accuracy: 0.8974654674530029
# 2023-05-26 15:08:43.020200: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 15:08:43.021510: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 15:08:43.022543: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 82/82 [==============================] - 18s 212ms/step
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.94      2171
#            1       0.66      0.78      0.72       433
#
#     accuracy                           0.90      2604
#    macro avg       0.81      0.85      0.83      2604
# weighted avg       0.91      0.90      0.90      2604

# %%
from typing import List

class CustomKerasModel(Sequential):
    def __init__(self, trial_id=None, **kwargs):
        super().__init__(**kwargs)
        self.trial_id = trial_id

def load_models_from_directory(directory_path: str) -> List[Sequential]:
    model_files = [name for name in os.listdir(directory_path) if name.endswith('.h5')]
    models = []
    for model_file in model_files:
        model_path = os.path.join(directory_path, model_file)
        model = load_model(model_path, custom_objects={'CustomKerasModel': CustomKerasModel})
        models.append(model)
    return models

def load_params(directory_path):
    param_file = os.path.join(directory_path, 'params.json')
    with open(param_file) as f:
        params = json.load(f)
    return params


def calculate_avg_probabilities(models: List[Sequential], X_test: np.ndarray) -> np.ndarray:
    # Initialize as zeros of type float64 with the number of samples
    avg_probabilities = np.zeros((X_test.shape[0],), dtype=np.float64)
    for model in models:
        y_prob = model.predict(X_test)
        avg_probabilities += y_prob.squeeze()  # Removes any unnecessary dimensions
    avg_probabilities /= len(models)
    return avg_probabilities

def plot_roc_curves(all_fpr, all_tpr, labels):
    plt.figure(figsize=(12, 8))
    for fpr, tpr, label in zip(all_fpr, all_tpr, labels):
        plt.plot(fpr, tpr, lw=2, label=label)

    plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve - Multiple Trials')
    plt.legend(loc='best')
    plt.show()


def main():
    root_directory = '/root/ray_results'
    experiment_directories = [name for name in os.listdir(root_directory) if os.path.isdir(os.path.join(root_directory, name))]

    all_fpr = []
    all_tpr = []
    labels = []

    for experiment_directory in experiment_directories:
        experiment_path = os.path.join(root_directory, experiment_directory)
        trial_directories = [name for name in os.listdir(experiment_path) if os.path.isdir(os.path.join(experiment_path, name))]

        for trial_directory in trial_directories:
            trial_path = os.path.join(experiment_path, trial_directory, 'ray_results', 'trial_None')

            models = load_models_from_directory(trial_path)
            if not models:
                continue

            # Read the params.json file
            with open(os.path.join(experiment_path, trial_directory, 'params.json'), 'r') as f:
                params = json.load(f)
                
            # Create a label using only certain parameters
            parameters_of_interest = ["optimizer", "batch_size", "dense_units", "dropout_rate", "epochs", "lstm_units", "num_dense_layers", "num_lstm_layers"]
            params_str = ", ".join(f"{key}: {params[key]}" for key in parameters_of_interest)
            label = f"{params_str}"
            labels.append(label)

            avg_probabilities = calculate_avg_probabilities(models, X_test)
            fpr, tpr, _ = roc_curve(y_test, avg_probabilities)
            all_fpr.append(fpr)
            all_tpr.append(tpr)

    plot_roc_curves(all_fpr, all_tpr, labels)



if __name__ == "__main__":
    main()
# Out:
# 2023-05-26 16:15:45.832133: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 16:15:45.833397: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 16:15:45.834376: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-26 16:15:46.001034: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 16:15:46.002079: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 16:15:46.003048: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-26 16:15:46.486359: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 16:15:46.487698: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 16:15:46.488689: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-26 16:15:46.648938: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 16:15:46.650001: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 16:15:46.650977: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 40/40 [==============================] - 18s 427ms/step
# 2023-05-26 16:16:04.065674: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 16:16:04.066952: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 16:16:04.067923: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-26 16:16:04.235581: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 16:16:04.236664: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 16:16:04.237629: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-26 16:16:04.809393: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 16:16:04.810776: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 16:16:04.811759: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-26 16:16:05.546680: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 16:16:05.548064: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 16:16:05.549059: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 40/40 [==============================] - 19s 439ms/step
# 2023-05-26 16:16:23.455963: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 16:16:23.457290: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 16:16:23.458277: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-26 16:16:23.944238: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 16:16:23.945594: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 16:16:23.946600: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 40/40 [==============================] - 9s 214ms/step
# 2023-05-26 16:16:32.807645: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 16:16:32.808958: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 16:16:32.809920: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-26 16:16:32.981416: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 16:16:32.982777: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 16:16:32.983940: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-26 16:16:33.469994: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 16:16:33.471323: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 16:16:33.472298: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-26 16:16:33.631716: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 16:16:33.632768: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 16:16:33.633739: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 40/40 [==============================] - 17s 425ms/step
# 2023-05-26 16:16:50.974986: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 16:16:50.976256: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 16:16:50.977243: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-26 16:16:51.144394: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 16:16:51.145422: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 16:16:51.146394: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-26 16:16:51.619122: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 16:16:51.620439: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 16:16:51.621435: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-26 16:16:51.782448: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 16:16:51.783494: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 16:16:51.784459: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 40/40 [==============================] - 17s 425ms/step
# 2023-05-26 16:17:09.106624: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 16:17:09.107909: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 16:17:09.108859: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-26 16:17:09.275563: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 16:17:09.276600: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 16:17:09.277543: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-26 16:17:09.750277: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 16:17:09.751617: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 16:17:09.752587: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-26 16:17:09.912372: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 16:17:09.913424: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 16:17:09.914420: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 40/40 [==============================] - 17s 423ms/step
# 2023-05-26 16:17:27.163487: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 16:17:27.164909: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 16:17:27.165879: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-26 16:17:27.653828: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 16:17:27.655208: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 16:17:27.656207: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 40/40 [==============================] - 9s 213ms/step
# 2023-05-26 16:17:36.475134: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 16:17:36.476429: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 16:17:36.477387: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-26 16:17:36.949171: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 16:17:36.950511: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 16:17:36.951486: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 40/40 [==============================] - 9s 211ms/step
# 2023-05-26 16:17:45.689845: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 16:17:45.691130: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 16:17:45.692134: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-26 16:17:45.858629: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 16:17:45.859650: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 16:17:45.860589: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-26 16:17:46.328847: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 16:17:46.330199: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 16:17:46.331191: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-26 16:17:46.493590: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 16:17:46.494659: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 16:17:46.495633: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 40/40 [==============================] - 17s 422ms/step
# 2023-05-26 16:18:03.723780: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 16:18:03.725068: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 16:18:03.726043: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-26 16:18:04.187301: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-26 16:18:04.188687: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-26 16:18:04.189669: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 26/40 [==================>...........] - ETA: 2s
